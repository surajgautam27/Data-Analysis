# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
children=[5,12,3,11,12]
color=['Red','blue','Black','Yellow','Green']
plt.bar(color,children)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(color,chhildren)

# %%
df=pd.read_csv('../Matplotlib/content/batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(df['batsman'],df['2015'])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(np.arange(df['batsman'].shape[0])-0.2,df['2015'],width=0.2)
plt.bar(np.arange(df['batsman'].shape[0]),df['2016'],width=0.2)
plt.bar(np.arange(df['batsman'].shape[0])+0.2,df['2017'],width=0.2)
# Out:
# <BarContainer object of 5 artists>

# %%
df['batsman'].shape[0]
# Out:
# 5

# %%
plt.bar(np.arange(df['batsman'].shape[0])-0.2,df['2015'],width=0.2)
plt.bar(np.arange(df['batsman'].shape[0]),df['2016'],width=0.2)
plt.bar(np.arange(df['batsman'].shape[0])+0.2,df['2017'],width=0.2)
plt.grid()
plt.xticks(np.arange(df['batsman'].shape[0]),df['batsman'],rotation='vertical')
plt.show()

# %%
plt.bar(df['batsman'],df['2015'])
plt.bar(df['batsman'],df['2016'],bottom=df['2015'])
plt.bar(df['batsman'],df['2017'],bottom=df['2016']+df['2015'])
# Out:
# <BarContainer object of 5 artists>

# %%
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308
