# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Advance-Matplotlib/Dataset/batter.csv')
df
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
fig=plt.figure()
ax=plt.figure(figsize=[15,12]).add_subplot(projection='3d')
ax.scatter(df['runs'],df['avg'],df['strike_rate'])
ax.set_title('Runs vs Avg vs Strike Rate')
ax.set_xlabel('Runs')
ax.set_ylabel('Average')
ax.set_zlabel('Strike Rate')
# Out:
# Text(0.5, 0, 'Strike Rate')

# %%
x=[0,5,10]
y=[0,10,20]
z=[0,20,40]
fig = plt.figure()
ax=plt.figure().add_subplot(projection='3d')
ax.scatter3D(x,y,z, s=[100,100,100], color='black')
ax.plot(x,y,z,color='red')

# %%
x=[0,5,10]
y=[0,0,20]
z=[0,20,40]
fig = plt.figure()
ax=plt.figure().add_subplot(projection='3d')
ax.scatter3D(x,y,z, s=[100,100,100], color='black')
ax.plot(x,y,z,color='red')

# %%
#3d Surface Plot
x=np.linspace(-10,10,100)
y= np.linspace(-10,10,100)
xx,yy = np.meshgrid(x,y)
z=xx**2+yy**2
fig= plt.figure()
ax=plt.figure().add_subplot(projection='3d')
data=ax.plot_surface(xx,yy,z,cmap='viridis')
fig.colorbar(data)

# %%
x=np.linspace(-10,10,100)
y= np.linspace(-10,10,100)
xx,yy = np.meshgrid(x,y)
z=xx**2+yy**2
fig= plt.figure()
ax=plt.figure().add_subplot()
data=ax.contour(xx,yy,z,cmap='viridis')
fig.colorbar(data)

# %%
x=np.linspace(-10,10,100)
y= np.linspace(-10,10,100)
xx,yy = np.meshgrid(x,y)
z=xx**2+yy**2
fig= plt.figure()
ax=plt.figure().add_subplot()
data=ax.contourf(xx,yy,z,cmap='viridis')
fig.colorbar(data)

# %%
data=pd.read_csv('../Advance-Matplotlib/Dataset/IPL_Ball_by_Ball_2008_2022.csv')
data
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
temp_data=data[(data['ballnumber']<=6) & (data['batsman_run']==6)]
new_data=temp_data.pivot_table(index='overs', columns='ballnumber',values='batsman_run', aggfunc='count')
new_data
plt.figure(figsize=(15,10))
plt.imshow(new_data)
plt.colorbar()
plt.xticks(ticks=[0,1,2,3,4,5,],labels=[1,2,3,4,5,6])
plt.yticks(ticks=np.arange(0,20),labels=np.arange(1,21))
plt.show()

# %%
#plotting using Pandas
import seaborn as sns

# %%
tips=sns.load_dataset('tips')

# %%
tips.plot('total_bill','tip', kind='scatter',color='black' ,marker='+', xlabel='Total bill' , ylabel='Tips', s=tips['size']*40)
# Out:
# <Axes: xlabel='Total bill', ylabel='Tips'>

# %%
tips['tip'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
