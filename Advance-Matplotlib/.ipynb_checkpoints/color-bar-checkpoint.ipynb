# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Advance-Matplotlib/Dataset/iris.csv')
df.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 85    86            6.0           3.4            4.5           1.6
# 108  109            6.7           2.5            5.8           1.8
# 120  121            6.9           3.2            5.7           2.3
# 21    22            5.1           3.7            1.5           0.4
# 15    16            5.7           4.4            1.5           0.4
# 130  131            7.4           2.8            6.1           1.9
# 30    31            4.8           3.1            1.6           0.2
# 145  146            6.7           3.0            5.2           2.3
# 66    67            5.6           3.0            4.5           1.5
#
#              Species
# 0        Iris-setosa
# 85   Iris-versicolor
# 108   Iris-virginica
# 120   Iris-virginica
# 21       Iris-setosa
# 15       Iris-setosa
# 130   Iris-virginica
# 30       Iris-setosa
# 145   Iris-virginica
# 66   Iris-versicolor

# %%
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'])

# %%
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'])
df['Species']=df['Species'].replace({'Iris-setosa':0,'Iris-virginica':1,'Iris-versicolor':2})
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        1
# 146  147            6.3           2.5            5.0           1.9        1
# 147  148            6.5           3.0            5.2           2.0        1
# 148  149            6.2           3.4            5.4           2.3        1
# 149  150            5.9           3.0            5.1           1.8        1
#
# [150 rows x 6 columns]

# %%
plt.figure(figsize=(15,7))
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'],c=df['Species'],cmap='summer',alpha=1)
plt.colorbar()
# plt.xlabel('SepalLengthCm')
# plt.ylabel('PetalLengthCm')

# %%
x=np.arange(1,5)
y=np.arange(6,10)
plt.scatter(x,y)
plt.text(1,6,'plot1', fontdict={'color':'red'})
plt.text(2,7,'plot2')
plt.text(3,8,'plot3')
plt.text(4,9,'plot4')
# Out:
# Text(4, 9, 'plot4')

# %%
batsman=pd.read_csv('../Advance-Matplotlib/Dataset/batter.csv')
batsman
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
batsman=batsman.sample(50)
batsman
# Out:
#                 batter  runs        avg  strike_rate
# 215        MF Maharoof   177  17.700000   142.741935
# 353            BR Dunk    40  13.333333   111.111111
# 202       Bipul Sharma   187  23.375000   150.806452
# 282            AD Nath    90   9.000000    90.909091
# 142            S Sohal   368  18.400000   118.327974
# 369           A Kumble    35  11.666667    71.428571
# 214            C Munro   177  14.750000   122.916667
# 289    NM Coulter-Nile    82   7.454545   109.333333
# 78             M Vohra  1073  22.354167   125.938967
# 267      Kuldeep Yadav   105  15.000000    80.769231
# 311          H Klaasen    66  13.200000   113.793103
# 97       ST Jayasuriya   768  27.428571   134.031414
# 576       Shoaib Ahmed     1   0.500000    16.666667
# 227   RE van der Merwe   159  14.454545   110.416667
# 241         UT Khawaja   127  21.166667   120.952381
# 266          LJ Wright   106  21.200000   168.253968
# 316      Anirudh Singh    63  15.750000    91.304348
# 305     Mohammed Shami    69   6.272727    93.243243
# 53           MK Tiwary  1695  28.728814   113.834788
# 137         MV Boucher   394  28.142857   123.899371
# 170          R Sathish   270  15.882353   114.406780
# 125        PC Valthaty   505  22.954545   116.898148
# 485            BB Sran    10  10.000000    71.428571
# 115        YBK Jaiswal   547  23.782609   133.414634
# 66           KH Pandya  1326  22.100000   132.203390
# 599           JL Denly     0   0.000000     0.000000
# 344            DR Sams    44   4.888889    91.666667
# 169         MJ Guptill   271  22.583333   137.563452
# 138          CA Pujara   390  20.526316    96.774194
# 559       Harshit Rana     2   2.000000   100.000000
# 371           M Ashwin    35   3.888889    70.000000
# 296          CR Woakes    78  13.000000   101.298701
# 502           UA Birla     7   7.000000    46.666667
# 516      PSP Handscomb     6   6.000000    50.000000
# 543          JE Taylor     3   3.000000    75.000000
# 79          MP Stoinis  1070  26.097561   131.611316
# 503         Ankit Soni     7   3.500000    77.777778
# 565  Mohammad Ashraful     2   2.000000    16.666667
# 330     Sandeep Sharma    52   8.666667    78.787879
# 14           SR Watson  3880  30.793651   134.163209
# 82        KP Pietersen  1001  35.750000   132.058047
# 428       Vishnu Vinod    19   6.333333    73.076923
# 29             M Vijay  2619  25.930693   118.614130
# 528          KS Sharma     4   4.000000   100.000000
# 342      Yashpal Singh    47  11.750000    70.149254
# 427             P Sahu    19  19.000000   146.153846
# 568            SB Wagh     2   1.000000    66.666667
# 6             CH Gayle  4997  39.658730   142.121729
# 405         ER Dwivedi    24  12.000000   160.000000
# 573          HF Gurney     1        NaN    20.000000

# %%
plt.figure(figsize=(20,12))
plt.scatter(batsman['avg'],batsman['strike_rate'])
for i in range(batsman.shape[0]):
    plt.text(batsman['avg'].values[i],batsman['strike_rate'].values[i],batsman['batter'].values[i])
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
