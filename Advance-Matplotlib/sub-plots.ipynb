# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Advance-Matplotlib/Dataset/batter.csv')
df
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
plt.scatter(df['avg'],df['runs'])
plt.xlabel('Average')
plt.ylabel('Runs')
plt.title('Runs VS Average')
# Out:
# Text(0.5, 1.0, 'Runs VS Average')

# %%
fig, ax=plt.subplots( figsize=[13,9])
ax.scatter(df['avg'],df['runs'] ,marker='+')
ax.set_title('Average Vs Runs')
ax.set_xlabel('Average')
ax.set_ylabel('Runs')
# Out:
# Text(0, 0.5, 'Runs')

# %%
fig, ax=plt.subplots(nrows=2,ncols=1,figsize=[15,9], sharex=True)
ax[0].scatter(df['avg'],df['runs'] ,marker='+')
ax[0].set_title('Average Vs Runs')
ax[0].set_ylabel('Runs')
ax[1].scatter(df['avg'],df['strike_rate'] ,marker='+')
ax[1].set_xlabel('Average')
ax[1].set_ylabel('Strike Rate')
# Out:
# Text(0, 0.5, 'Strike Rate')

# %%
fig, ax=plt.subplots(nrows=2,ncols=2,figsize=[15,9])
ax[0,0].scatter(df['avg'],df['runs'])
ax[0,1].scatter(df['avg'],df['strike_rate'] )
ax[1,0].hist(df['avg'])
ax[1,1].hist(df['runs'])
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %%
x=[1,2,3,4,5,-6,-7]
y=[-1,-2,4,3,9,-1,-11]
plt.scatter(x,y)
plt.axhline(0)
plt.axvline(0)

# %%
df
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]
